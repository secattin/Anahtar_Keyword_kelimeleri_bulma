# %%
import pandas as pd
import nltk
import string
import re

# %%
#m1 isimli dergi içn keyword listesi
m1_kw=pd.read_csv("m1.csv") 
m2_kw=pd.read_csv("m2.csv") 
m3_kw=pd.read_csv("m3.csv")
m4_kw=pd.read_csv("m4.csv")
m5_kw=pd.read_csv("m5.csv")
m5a_kw=pd.read_csv("m5a.csv")
m6_kw=pd.read_csv("m6.csv")
m7_kw=pd.read_csv("m7.csv")
m7a_kw=pd.read_csv("m7a.csv")
m8_kw=pd.read_csv("m8.csv")
m9_kw=pd.read_csv("m9.csv")
m10_kw=pd.read_csv("m10.csv")
m11_kw=pd.read_csv("m11.csv")
m11b_kw=pd.read_csv("m11b.csv")
m12_kw=pd.read_csv("m12.csv")
m13_kw=pd.read_csv("m13.csv")
m14_kw=pd.read_csv("m14.csv")
m15_kw=pd.read_csv("m15.csv")
m17_kw=pd.read_csv("m17.csv")
m17a_kw=pd.read_csv("m17a.csv")
m18_kw=pd.read_csv("m18.csv")
m19_kw=pd.read_csv("m19.csv")
m20_kw=pd.read_csv("m20.csv")
m21_kw=pd.read_csv("m21.csv")
m21a_kw=pd.read_csv("m21a.csv")
m22_kw=pd.read_csv("m22.csv")
m23_kw=pd.read_csv("m23.csv")
m24_kw=pd.read_csv("m24.csv")
m25_kw=pd.read_csv("m25.csv")
m26_kw=pd.read_csv("m26.csv")
m27_kw=pd.read_csv("m27.csv")
m28_kw=pd.read_csv("m28.csv")
m29_kw=pd.read_csv("m29.csv")
m30_kw=pd.read_csv("m30.csv")
m30a_kw=pd.read_csv("m30a.csv")
m31_kw=pd.read_csv("m31.csv")
m32_kw=pd.read_csv("m32.csv")
m32a_kw=pd.read_csv("m32a.csv")
m33_kw=pd.read_csv("m33.csv")
m33a_kw=pd.read_csv("m33a.csv")
m34_kw=pd.read_csv("m34.csv")
m34a_kw=pd.read_csv("m34a.csv")
m35_kw=pd.read_csv("m35.csv")
m35a_kw=pd.read_csv("m35a.csv")
m36_kw=pd.read_csv("m36.csv")
m37_kw=pd.read_csv("m37.csv")
m38_kw=pd.read_csv("m38.csv")
m39_kw=pd.read_csv("m39.csv")

# %%
df = pd.concat([m1_kw ,m2_kw ,m3_kw,m4_kw,m5_kw,m5a_kw,m6_kw,m7_kw,m7a_kw,m8_kw,m9_kw,m10_kw,m11_kw,m11b_kw,m12_kw,m13_kw,m14_kw,m15_kw,
               m17_kw,m17a_kw,m18_kw,m19_kw,m19_kw,m20_kw,m21_kw,m21a_kw,m22_kw,m24_kw,m25_kw,m26_kw,m27_kw,m28_kw,m29_kw,m30_kw,
               m31_kw,m32_kw,m33_kw,m33a_kw,m34_kw,m34a_kw,m35_kw,m35a_kw,m36_kw,m23_kw,m37_kw,m38_kw,m39_kw,m30a_kw,m32a_kw],ignore_index=True)
df.shape
# Out:
# (56450, 24)

# %%
#for row in df.iterrows():
   # print (row)

# %%
df['Author Keywords'] = df['Author Keywords'].drop_duplicates()

# %%
df['Author Keywords'] = df['Author Keywords'].str.lower() # küçük harf yazdırma

# %%
kw=df['Author Keywords']

# %%
kw_listesi=[]

# %%
for x in range(56446):
    for i in str(kw[x]).split(";"):
        kw_listesi.append(i.strip())
         
kw_listesi
# Out:
# ['action mechanism',
#  'collaborative innovative learning (cil)',
#  'knowledge flow',
#  'learning platform',
#  'multi-factor variable',
#  'robustness',
#  'cyber security',
#  'distance education',
#  'university students',
#  'acting path',
#  'experiment course',
#  'sem analysis',
#  'teaching effect',
#  'virtual simulation',
#  'digital graphic design teaching',
#  'optimization of teaching behaviors',
#  'virtual reality technology',
#  'cognitive engagement',
#  'creative thinking',
#  'critical thinking',
#  'physic learning',
#  'quantum flipped learning model',
#  'artificial intelligence in education',
#  'artificial intelligence-based instructional technology',
#  'vietnamese middle schools',
#  'digcompedu',
#  'digital competence',
#  'higher education',
#  'information and communication technologies',
#  'distance',
#  'internet of things for university students',
#  'cloud computing',
#  'fog computing',
#  'resource allocation',
# ...

# %%
ozett='Online learning can potentially meet increasingly diverse students needs in higher education, including disabled students. However, institutions have historically struggled in providing accessible and inclusive online learning.Higher education online learning leaders, those who manage instructional designers, are in a unique position to help institutions strategize and create accessible and inclusive online courses.In this qualitative study, we interviewed nine higher education online learning leaders to understand leaders’ perceptions about how institutions provide accessible and inclusive online learning.Results demonstrated that despite varying conceptualizations of accessibility and inclusivity,online learning leaders perceive an insufficient but growing emphasis in higher education.Overall, participants described instructional designers as the most knowledgeable and skilled in this area. Participants described a lack of agency for instructional design teams and a need to advocate for buy-in from senior leadership.They also described strategies (e.g., faculty development, quality standards, and accessibility checkers) to support faculty'

# %%
ozett
# Out:
# 'Online learning can potentially meet increasingly diverse students needs in higher education, including disabled students. However, institutions have historically struggled in providing accessible and inclusive online learning.Higher education online learning leaders, those who manage instructional designers, are in a unique position to help institutions strategize and create accessible and inclusive online courses.In this qualitative study, we interviewed nine higher education online learning leaders to understand leaders’ perceptions about how institutions provide accessible and inclusive online learning.Results demonstrated that despite varying conceptualizations of accessibility and inclusivity,online learning leaders perceive an insufficient but growing emphasis in higher education.Overall, participants described instructional designers as the most knowledgeable and skilled in this area. Participants described a lack of agency for instructional design teams and a need to advoca
# ...

# %%
ozett.split()
# Out:
# ['Online',
#  'learning',
#  'can',
#  'potentially',
#  'meet',
#  'increasingly',
#  'diverse',
#  'students',
#  'needs',
#  'in',
#  'higher',
#  'education,',
#  'including',
#  'disabled',
#  'students.',
#  'However,',
#  'institutions',
#  'have',
#  'historically',
#  'struggled',
#  'in',
#  'providing',
#  'accessible',
#  'and',
#  'inclusive',
#  'online',
#  'learning.Higher',
#  'education',
#  'online',
#  'learning',
#  'leaders,',
#  'those',
#  'who',
#  'manage',
#  'instructional',
#  'designers,',
#  'are',
#  'in',
#  'a',
#  'unique',
#  'position',
#  'to',
#  'help',
#  'institutions',
#  'strategize',
#  'and',
#  'create',
#  'accessible',
#  'and',
#  'inclusive',
#  'online',
#  'courses.In',
#  'this',
#  'qualitative',
#  'study,',
#  'we',
#  'interviewed',
#  'nine',
#  'higher',
#  'education',
#  'online',
#  'learning',
#  'leaders',
#  'to',
#  'understand',
#  'leaders’',
#  'perceptions',
#  'about',
#  'how',
#  'institutions',
#  'provide',
# ...

# %%
ozet=pd.Series(['online','learning','can','potentially', 'meet','increasingly','diverse','students','needs' 'in','higher','education''including' 'disabled', 'students.','However,','institutions','have','historically','struggled','in','providing','accessible''and','inclusive','online','learning.Higher','education','online','learning','leaders,','those','who','manage','instructional','designers,','are','in','a','unique','position','to','help','institutions','strategize','and','create''accessible','and','inclusive', 'courses.In','this', 'qualitative','study,', 'we' 'interviewed', 'nine', 'higher', 'education',  'learning', 'leaders', 'to', 'understand', 'leaders’', 'perceptions', 'about', 'how' 'institutions' 'provide', 'accessible', 'and', 'inclusive', 'online', 'learning.Results', 'that', 'despite','varying', 'conceptualizations', 'of', 'accessibility', 'and', 'inclusivity,online', 'learning', 'leaders', 'perceive', 'an' 'insufficient', 'but', 'growing', 'emphasis', 'in', 'higher', 'education.Overall,', 'participants', 'described','instructional', 'designers', 'as', 'most', 'knowledgeable','and' 'skilled','in' 'this', 'area.', 'Participants', 'described', 'a', 'lack','of','agency', 'for','instructional','design', 'teams', 'and', 'a','need','to','advocate','for','buy-in','from','senior','leadership.They','also','described','strategies','(e.g.,','faculty','development,','quality','standards,','and','accessibility','checkers)','to','support'])

# %%
ozet=ozet.str.lower()

# %%
ozet=ozet.drop_duplicates()

# %%
kw_listesi
# Out:
# ['action mechanism',
#  'collaborative innovative learning (cil)',
#  'knowledge flow',
#  'learning platform',
#  'multi-factor variable',
#  'robustness',
#  'cyber security',
#  'distance education',
#  'university students',
#  'acting path',
#  'experiment course',
#  'sem analysis',
#  'teaching effect',
#  'virtual simulation',
#  'digital graphic design teaching',
#  'optimization of teaching behaviors',
#  'virtual reality technology',
#  'cognitive engagement',
#  'creative thinking',
#  'critical thinking',
#  'physic learning',
#  'quantum flipped learning model',
#  'artificial intelligence in education',
#  'artificial intelligence-based instructional technology',
#  'vietnamese middle schools',
#  'digcompedu',
#  'digital competence',
#  'higher education',
#  'information and communication technologies',
#  'distance',
#  'internet of things for university students',
#  'cloud computing',
#  'fog computing',
#  'resource allocation',
# ...

# %%
for i in ozet:
    if i in kw_listesi:
        print(i)
# Out:
# online
# learning
# students
# higher
# institutions
# inclusive
# education
# who
# instructional
# help
# and
# qualitative
# leaders
# perceptions
# accessible
# conceptualizations
# accessibility
# agency
# design
# teams
# need
# strategies
# faculty
# quality
# support

# %%
def ozetbul():    
    for i in ozet:
         if i in kw_listesi:
                print(i)
                
                
ozet='online', 'learning','can ','potentially',' meet increasingly', 'diverse','students'
kw_listesi='online','learning','diverse','potentially'
ozetbul()
# Out:
# online
# learning
# potentially
# diverse

# %%
metin= '''Distance education celebrates its humanitarian mission of providing opportunities for disadvantaged and marginalized individuals who do not have access to traditional 
campus-based higher education. Large enrolments of students necessitate an industrialized approach in planning,
design, and delivery informed by a normative assumption of ableism. In the context of post-apartheid South Africa, distance education fulfills a particular important role in ensuring access to education for all. This scoping review addressed two questions: “What is currently known, in the context of distance education in South Africa, about the educational experiences of SWDs?”
and “How should we understand and respond to these experiences?” The scoping study shows, inter alia, that while there is an institutional 
commitment to providing equitable learning experiences, the lived experiences of students with disabilities provide evidence of their invisibility in the design, planning, 
and delivery of learning. The study concludes with some recommendations and provocations.'''

kw_listt=['mission of providi', 'This', 'humanitarian mission', 'correct']
def bul(metin):
    f=[]
    for words in kw_listt:
        if re.search(r'\b' + words + r'\b', metin):
           f.append(words)
    return f

# %%
a=str.split(df["Author Keywords"][0],";")

# %%
m1_kw["Author Keywords"] #m1 keyword listesi
# Out:
# 0       Action mechanism; Collaborative innovative lea...
# 1       Cyber security; Distance education; University...
# 2       Acting path; Experiment course; Sem analysis; ...
# 3       Digital graphic design teaching; Optimization ...
# 4       Cognitive engagement; Creative thinking; Criti...
#                               ...
# 1788    Auto-ethnography; Second-language teacher educ...
# 1789    Augmented reality; Scientific imagineering; ST...
# 1790    Attitudes; Coding; Flipped classroom; Game; Ga...
# 1791    Constraint-based modeling; Intelligent tutorin...
# 1792    Debriefing; Immunological techniques; Learning...
# Name: Author Keywords, Length: 1793, dtype: object

# %%
m2_kw["Author Keywords"] #m2 keyword listesi
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      Chinese students; Community of Inquiry (CoI); ...
#                              ...
# 613                                                  NaN
# 614                                                  NaN
# 615                                                  NaN
# 616                                                  NaN
# 617                                                  NaN
# Name: Author Keywords, Length: 618, dtype: object

# %%
 
a=str.split(m4_kw["Author Keywords"][0],";")
b=str.split(m4_kw["Author Keywords"][1],";")
b
# Out:
# ['Educational technology',
#  ' Evidence',
#  ' Expertise',
#  ' Myths',
#  ' Qualitative research',
#  ' Quantitative research']

# %%
m3_kw["Author Keywords"]

# %%
m3_kw["Index Keywords"]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1979   NaN
# 1980   NaN
# 1981   NaN
# 1982   NaN
# 1983   NaN
# Name: Index Keywords, Length: 1984, dtype: float64

# %%
m4_kw["Author Keywords"]
# Out:
# 0      Artificial intelligence; Education technology;...
# 1      Educational technology; Evidence; Expertise; M...
# 2      Computing education; Online teacher education;...
# 3      Academic emotions; English as a medium of inst...
# 4      Higher education research; Methodological guid...
#                              ...
# 973                                                  NaN
# 974                                                  NaN
# 975                                                  NaN
# 976                                                  NaN
# 977                                                  NaN
# Name: Author Keywords, Length: 978, dtype: object

# %%
m5_kw["Author Keywords"]
# Out:
# 0       disability; e-learning; special education; spe...
# 1                                                     NaN
# 2       higher education; inclusiveness; Instagram; le...
# 3       blockchain technology; education commons; educ...
# 4       actor network theory; collaboration; computing...
#                               ...
# 1774                                                  NaN
# 1775                                                  NaN
# 1776                                                  NaN
# 1777                                                  NaN
# 1778                                                  NaN
# Name: Author Keywords, Length: 1779, dtype: object

# %%
m5a_kw["Author Keywords"]
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 598   NaN
# 599   NaN
# 600   NaN
# 601   NaN
# 602   NaN
# Name: Author Keywords, Length: 603, dtype: float64

# %%
m6_kw["Author Keywords"]
# Out:
# 0      Applied Linguistics; BRaVE Program; Brazilian ...
# 1      Computer-mediated communication; face to face ...
# 2      Caption types; foreign language learning; list...
# 3      Blended Learning; Brunei; Flipped Classroom; H...
# 4      Cognitive Processes; Eye-Tracking Research; Pi...
#                              ...
# 124    Action research; Global citizenship; Intercult...
# 125    Affordances; CAVL; Digital flashcards; English...
# 126    Affordances; English course; Participation; Se...
# 127    Blogs; Fully online learning; L2 Writing; Peer...
# 128    Benchmarks; High-stakes tests; Lexical profile...
# Name: Author Keywords, Length: 129, dtype: object

# %%
m7_kw["Author Keywords"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1011    NaN
# 1012    NaN
# 1013    NaN
# 1014    NaN
# 1015    NaN
# Name: Author Keywords, Length: 1016, dtype: object

# %%
m7a_kw["Author Keywords"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1056    NaN
# 1057    NaN
# 1058    NaN
# 1059    NaN
# 1060    NaN
# Name: Author Keywords, Length: 1061, dtype: object

# %%
m8_kw["Author Keywords"]
# Out:
# 0       Associations within subjects; Item addressee; ...
# 1       Epistemic cognition; Intervention study; Multi...
# 2       Adaptability; Job Demands-Resources model; Sel...
# 3                                                     NaN
# 4       Academic adjustment; Education; Motivation; Pa...
#                               ...
# 1773                                                  NaN
# 1774                                                  NaN
# 1775                                                  NaN
# 1776                                                  NaN
# 1777                                                  NaN
# Name: Author Keywords, Length: 1778, dtype: object

# %%
m9_kw["Author Keywords"]
# Out:
# 0                                                     NaN
# 1       cognitive presence; indicators; social presenc...
# 2       conservatories; COVID-19; music education; rem...
# 3       academic performance; early participation; lar...
# 4       expectancy-value theory; longitudinal study; o...
#                               ...
# 1047                                                  NaN
# 1048                                                  NaN
# 1049                                                  NaN
# 1050                                                  NaN
# 1051                                                  NaN
# Name: Author Keywords, Length: 1052, dtype: object

# %%
m10_kw["Author Keywords"]
# Out:
# 0      arithmetic progression; Credit share; governin...
# 1      ICT; learning styles; module; Orang Asli students
# 2      cognitive abilities; Educational game; gamifie...
# 3      Practical skills development; scientific inves...
# 4      active learning; Blended learning; flipped cla...
#                              ...
# 569    Higher education management; Process improveme...
# 570    Animated video; Differentiated instruction; Ed...
# 571    Cultural and creative products; Information te...
# 572    Field learning; Remedial instruction; Teacher ...
# 573    4D teaching method; Agricultural marketing; In...
# Name: Author Keywords, Length: 574, dtype: object

# %%
m11_kw["Author Keywords"]
# Out:
# 0       education; integration; migration; Scotland; t...
# 1       digital infrastructure; digital strategies; ed...
# 2       active learning; calculus; collaboration; math...
# 3       affordances; early childhood education; educat...
# 4       clinical experience; engineering education; pr...
#                               ...
# 1853    Experiential learning; First year experience; ...
# 1854    Creativity; Education assessment; Student expe...
# 1855    General education; Geography education; Higher...
# 1856    Compassion; Compassion-focused parenting; Nurt...
# 1857    3D-geometric shapes; Augmented Reality; Geomet...
# Name: Author Keywords, Length: 1858, dtype: object

# %%
m11b_kw["Author Keywords"]
# Out:
# 0      Emotional attachment; Inclusion; Learning disp...
# 1      Flipped-classroom; Gamification; Motivation; S...
# 2      Family education; Parenting education; Technol...
# 3      Exemplarity; Global justice; Higher education;...
# 4      Active learning methods; Flipped classroom; Ga...
#                              ...
# 735    AI; Computer science; Fuzzy logic; Mathematica...
# 736    Civics and citizenship education; Critical ped...
# 737    Digital divide; Home and school; Internet acce...
# 738                                                  NaN
# 739    Drug databases; E-learning; Further and contin...
# Name: Author Keywords, Length: 740, dtype: object

# %%
m12_kw["Author Keywords"]
# Out:
# 0      Consensual Assessment Technique; Creativity; M...
# 1      Calculus; Desirable difficulty; Engineering; R...
# 2      Authentic learning; Cognitive and motivational...
# 3      Affective processing; Head mounted display; Im...
# 4                                                    NaN
#                              ...
# 993                        elaboration; learning; memory
# 994                                                  NaN
# 995    instruction; mathematics; sex differences; sex...
# 996    cognition; individual differences; memory; mot...
# 997            cognition; reading; reading comprehension
# Name: Author Keywords, Length: 998, dtype: object

# %%
m13_kw["Author Keywords"]
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2      Academic performance; Meta-analysis; Peer-asse...
# 3      Community; Family; Impact; Student; Successful...
# 4      Embodied learning; First language; Foreign lan...
#                              ...
# 397    Affect; Learning; Metacognition; Metacognitive...
# 398                                                  NaN
# 399    Gold standard; NRC report; Randomized field tr...
# 400                                                  NaN
# 401                                                  NaN
# Name: Author Keywords, Length: 402, dtype: object

# %%
m14_kw["Author Keywords"]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1014   NaN
# 1015   NaN
# 1016   NaN
# 1017   NaN
# 1018   NaN
# Name: Author Keywords, Length: 1019, dtype: float64

# %%
m15_kw["Author Keywords"]
# Out:
# 0       at-risk students; econometric analysis; educat...
# 1       adolescence; diversity; focus group interviews...
# 2       descriptive analysis; diversity; equity; highe...
# 3       equity; poverty; regression analyses; secondar...
# 4       educational policy; educational reform; organi...
#                               ...
# 1243                                                  NaN
# 1244                                                  NaN
# 1245                                                  NaN
# 1246                                                  NaN
# 1247                                                  NaN
# Name: Author Keywords, Length: 1248, dtype: object

# %%
m17_kw["Author Keywords"]
# Out:
# 0                                                     NaN
# 1       Concept mapping; Flipped learning; Interactive...
# 2       Self-regulated learning; Teacher emotion; Tech...
# 3       Distance education; Inservice teachers; Learni...
# 4                                                     NaN
#                               ...
# 1692                                                  NaN
# 1693                                                  NaN
# 1694                                                  NaN
# 1695                                                  NaN
# 1696                                                  NaN
# Name: Author Keywords, Length: 1697, dtype: object

# %%
m17a_kw["Author Keywords"]
# Out:
# 0      Beginning secondary teachers; Good mathematics...
# 1      Alternative conception; Epistemological percep...
# 2      Basic physics; Experimental devices; Problem s...
# 3      Cooperative learning; Cultural difference; Mat...
# 4      Teacher conceptions; Teacher education; Visual...
#                              ...
# 190    Correlations; Gender; Genetics achievement tes...
# 191    Pre-service elementary teachers; Science Teach...
# 192    Achievement; Mathematics anxiety; Matriculatio...
# 193    Science teaching; Scientist; The Draw-a-Scient...
# 194    Attitudes; Learning styles; Mathematics; Pre-s...
# Name: Author Keywords, Length: 195, dtype: object

# %%
m18_kw["Author Keywords"]
# Out:
# 0      Automatic measurement; Indicators; Log data; P...
# 1      Role assignment; Social presence; The communit...
# 2      Internet self-efficacy; Online academic help-s...
# 3      Academic engagement; Academic integration; Adu...
# 4      Course design; Course load; Enrollment data; L...
#                              ...
# 687                                                  NaN
# 688                                                  NaN
# 689                                                  NaN
# 690                                                  NaN
# 691                                                  NaN
# Name: Author Keywords, Length: 692, dtype: object

# %%
m19_kw["Author Keywords"]
# Out:
# 0       CMOOC; connectivism; influencing factors; inte...
# 1       mobile legends; online learning module; Physic...
# 2       Bibliometric analysis; robots; science educati...
# 3       blended learning; higher vocational college; i...
# 4       Basic medical sciences; creativity; instructio...
#                               ...
# 1647                                                  NaN
# 1648                                                  NaN
# 1649                                                  NaN
# 1650                                                  NaN
# 1651                                                  NaN
# Name: Author Keywords, Length: 1652, dtype: object

# %%
m20_kw["Author Keywords"]
# Out:
# 0      Academic Second-and-Third-Year Grades; CGPA Pr...
# 1      Adaptative learning; E-learning; Educational r...
# 2      COVID-19; D&M IS success model; E-learning; In...
# 3      Agile; Learning Assessment; Project-Based lear...
# 4      Learning Analytics; Online Discussion; Social ...
#                              ...
# 431    communication traffic; delay; distance learnin...
# 432    courseware engineering methodology; distance l...
# 433    eXtensible markup language; Java Server Pages;...
# 434    e-learning; task-based learning; total quality...
# 435    communication technology; distance learning; h...
# Name: Author Keywords, Length: 436, dtype: object

# %%
m21_kw["Author Keywords"]
# Out:
# 0      Azure-PaaS; cloud computing; Online education;...
# 1      Academic assessment; Academic programs; End of...
# 2      B/s; Online english; Self-learning; System dev...
# 3      Computer-aided teaching; English words; Memory...
# 4      Language learning; Morphology analysis; Part o...
#                              ...
# 783    Cognitive development; Education; Learning sys...
# 784    Interactive cultural learning; International e...
# 785    Culture; Multimedia courseware; Taiwan; Trade ...
# 786                      Didactics; e-learning; Ontology
# 787    Collaborative filtering; Latent semantic analy...
# Name: Author Keywords, Length: 788, dtype: object

# %%
m21a_kw["Author Keywords"]
# Out:
# 0      Active learning; Artificial intelligence; Curr...
# 1                                                    NaN
# 2                    Clustering; Machine learning; MOOCs
# 3      e-Learning; Feedback; Frame of reference; Refe...
# 4                                                    NaN
#                              ...
# 347    Assessment; e-learning; Learning outcomes; Web...
# 348    Absolute judgements; Comparative judgement; Cr...
# 349    Assessment; Competencies; Feedforward; Peer-Fe...
# 350    Continuous e-assessment; E-learning; ICT; Inte...
# 351    Education; Flipped classroom; Teaching innovat...
# Name: Author Keywords, Length: 352, dtype: object

# %%
m22_kw["Author Keywords"]
# Out:
# 0       benefits; e-learning; engineering education; e...
# 1       COVID-19; Oman; perceptions; practicum; pre-se...
# 2       competencies; descriptive-correlational study;...
# 3       coronavirus; Covid-19; e-learning; e-teaching ...
# 4       assessment; evaluation; implementation; LVCPM ...
#                               ...
# 1335    Behavioural intention; Computer use; Student t...
# 1336    EFL teacher education; Implementation Strategi...
# 1337    Distance learning; IGNOU; Interactive multimed...
# 1338    Assessmenttasks; Canonical analysis; Classroom...
# 1339    Attitude; Inclusion; Inclusive education; Pre-...
# Name: Author Keywords, Length: 1340, dtype: object

# %%
m23_kw["Author Keywords"]
# Out:
# 0       distance education and online learning; inform...
# 1       higher education; OCW; OEP; OER; open educatio...
# 2       BERT; cognitive MOOC classification; LSTM; tra...
# 3       COVID-19; learning ineffectiveness; online lea...
# 4       community of inquiry; distance education; self...
#                               ...
# 1281                                                  NaN
# 1282                                                  NaN
# 1283                                                  NaN
# 1284                                                  NaN
# 1285                                                  NaN
# Name: Author Keywords, Length: 1286, dtype: object

# %%
m24_kw["Author Keywords"]
# Out:
# 0       attention cueing; example-based learning; eye ...
# 1       cognitive load theory; cognitive theory of mul...
# 2       formative assessment cycle; online formative a...
# 3       academic integrity; assessment design; cheatin...
# 4       blended learning; K-12; meta-analysis; student...
#                               ...
# 1704                      CAL; Hearing‐impaired; Language
# 1705    Evaluation; Information technology; Literacy; ...
# 1706                                                  NaN
# 1707    Input devices; Keyboards; Output devices; Spec...
# 1708         Attitudes; CAL; Dialogue; Learning; Tutorial
# Name: Author Keywords, Length: 1709, dtype: object

# %%
m25_kw["Author Keywords"]
# Out:
# 0       academic performance; active learning; cogniti...
# 1       digital reading; large-scale assessment; machi...
# 2       kindergarten; mental rotation; preschool; robo...
# 3       digital literacy; evidence credibility; intern...
# 4       computer programming; serious games; support d...
#                               ...
# 1326                                                  NaN
# 1327                                                  NaN
# 1328                                                  NaN
# 1329                                                  NaN
# 1330                                                  NaN
# Name: Author Keywords, Length: 1331, dtype: object

# %%
m26_kw["Author Keywords"]
# Out:
# 0       Blockchain; Cryptography; Ethereum; Online ass...
# 1       Grounded theory; Online education; Psychologic...
# 2       Chatbot; Teacher efficacy; Teaching simulation...
# 3       Creativity; Divergent thinking; Interaction; R...
# 4       Blockchain; Education theory; Online learning;...
#                               ...
# 1927                                                  NaN
# 1928                                                  NaN
# 1929                                                  NaN
# 1930                                                  NaN
# 1931                                                  NaN
# Name: Author Keywords, Length: 1932, dtype: object

# %%
m27_kw["Author Keywords"]
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Computer-based Speaking Assessments; Fluency; ...
# 4      Computer-Assisted Language Learning (CALL); Sp...
#                              ...
# 617                                                  NaN
# 618                                                  NaN
# 619                                                  NaN
# 620                                                  NaN
# 621                                                  NaN
# Name: Author Keywords, Length: 622, dtype: object

# %%
m28_kw["Author Keywords"]
# Out:
# 0       Engagement; Learning outcome; Longitudinal mod...
# 1       Individual differences; Latent profile transit...
# 2       Comprehension monitoring; Interest; Mind wande...
# 3                                                     NaN
# 4       Attention-related behavior; Classroom instruct...
#                               ...
# 1461                                                  NaN
# 1462                                                  NaN
# 1463                                                  NaN
# 1464                                                  NaN
# 1465                                                  NaN
# Name: Author Keywords, Length: 1466, dtype: object

# %%
m29_kw["Author Keywords"]
# Out:
# 0      assemblage theory; COVID-19; decolonial and in...
# 1      artificial intelligence; automated decision-ma...
# 2      classroom ethnography; digitalization; learnin...
# 3                                                    NaN
# 4      data activism; Data gaze; data-bodies; higher ...
#                              ...
# 585                                                  NaN
# 586                                                  NaN
# 587                                                  NaN
# 588                                                  NaN
# 589                                                  NaN
# Name: Author Keywords, Length: 590, dtype: object

# %%
m30_kw["Author Keywords"]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1176   NaN
# 1177   NaN
# 1178   NaN
# 1179   NaN
# 1180   NaN
# Name: Author Keywords, Length: 1181, dtype: float64

# %%
m30a_kw["Author Keywords"]
# Out:
# 0       elementary; interventions; mathematics difficu...
# 1       diversity; equity; meta-analysis; research-pra...
# 2       early childhood; ecological theory; expulsion;...
# 3       critical bifocality; inequity; marginalization...
# 4       dyslexia; implicit learning; meta-analysis; st...
#                               ...
# 1912                                                  NaN
# 1913                                                  NaN
# 1914                                                  NaN
# 1915                                                  NaN
# 1916                                                  NaN
# Name: Author Keywords, Length: 1917, dtype: object

# %%
m31_kw["Author Keywords"]
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
#                             ...
# 68                                                  NaN
# 69    Adult literacy; Computer-based learning; Devel...
# 70                                                  NaN
# 71                                                  NaN
# 72                                                  NaN
# Name: Author Keywords, Length: 73, dtype: object

# %%
m32_kw["Author Keywords"]
# Out:
# 0       career capital; feminist bourdieusian scholars...
# 1       agency; conceptual framework; Cosmopolitanism;...
# 2       DEI; Diversity; diversity statement; equity; h...
# 3       academic career; China; doctoral education; id...
# 4       contributions of higher education; Higher educ...
#                               ...
# 1961                                                  NaN
# 1962                                                  NaN
# 1963                                                  NaN
# 1964                                                  NaN
# 1965                                                  NaN
# Name: Author Keywords, Length: 1966, dtype: object

# %%
m32a_kw["Author Keywords"]
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 660   NaN
# 661   NaN
# 662   NaN
# 663   NaN
# 664   NaN
# Name: Author Keywords, Length: 665, dtype: float64

# %%
m33_kw["Author Keywords"] #m33 keyword listesi
# Out:
# 0                                                     NaN
# 1       Accuracy; CALL; Complexity; Computer assisted ...
# 2       Consonant length contrast; Geminates; Italian;...
# 3       Assessment; English language teachers; Higher ...
# 4       Facial expression alignment; Interactive align...
#                               ...
# 1726                                                  NaN
# 1727                                                  NaN
# 1728                                                  NaN
# 1729                                                  NaN
# 1730                                                  NaN
# Name: Author Keywords, Length: 1731, dtype: object

# %%
m33a_kw["Author Keywords"] #m33a keyword listesi
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 762    NaN
# 763    NaN
# 764    NaN
# 765    NaN
# 766    NaN
# Name: Author Keywords, Length: 767, dtype: object

# %%
m34_kw["Author Keywords"] #m34 keyword listesi
# Out:
# 0                                                     NaN
# 1       Austria; Newly qualified teachers; Support mea...
# 2       Mixed methods; Professional development; Secon...
# 3       Eye-tracking; Knowledge-based reasoning; Mixed...
# 4       COVID-19 pandemic; Emotional exhaustion; Resou...
#                               ...
# 1887    Class size reduction; Professional development...
# 1888    Culturally responsive pedagogy; Literacy; Prac...
# 1889    Case studies; School culture; Student teaching...
# 1890        Career; Future; Motivation; Optimism; Teacher
# 1891    Bilingualism; Heritage education; Program effe...
# Name: Author Keywords, Length: 1892, dtype: object

# %%
m34a_kw["Author Keywords"] #m34a keyword listesi
# Out:
# 0       Community of practice; Discourse community; Ma...
# 1       Cross-cultural; Cultural immersion; Field expe...
# 2       Collaborative curriculum design; Curriculum in...
# 3       Digital technologies; Disruptive pedagogies; S...
# 4       Critical discourse analysis; Habermas; Human r...
#                               ...
# 1833                                                  NaN
# 1834                                                  NaN
# 1835                                                  NaN
# 1836                                                  NaN
# 1837                                                  NaN
# Name: Author Keywords, Length: 1838, dtype: object

# %%
m35_kw["Author Keywords"] #m35 keyword listesi
# Out:
# 0                                                     NaN
# 1                                                     NaN
# 2       Computational thinking in education; Computer ...
# 3       Metaverse; Second Life; Virtual reality; Virtu...
# 4                                                     NaN
#                               ...
# 1160                                                  NaN
# 1161    "Smart machines" riddle; Educational technolog...
# 1162                                                  NaN
# 1163                                                  NaN
# 1164                                                  NaN
# Name: Author Keywords, Length: 1165, dtype: object

# %%
m35a_kw["Author Keywords"] #m35a keyword listesi
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1093    NaN
# 1094    NaN
# 1095    NaN
# 1096    NaN
# 1097    NaN
# Name: Author Keywords, Length: 1098, dtype: object

# %%
m36_kw["Author Keywords"] #m36 keyword listesi
# Out:
# 0      Automatic measurement; Indicators; Log data; P...
# 1      Role assignment; Social presence; The communit...
# 2      Internet self-efficacy; Online academic help-s...
# 3      Academic engagement; Academic integration; Adu...
# 4      Course design; Course load; Enrollment data; L...
#                              ...
# 687                                                  NaN
# 688                                                  NaN
# 689                                                  NaN
# 690                                                  NaN
# 691                                                  NaN
# Name: Author Keywords, Length: 692, dtype: object

# %%
m37_kw["Author Keywords"] #m37 keyword listesi
# Out:
# 0       E-modules; Learning oucomes; Motivation; Onlin...
# 1       Challenge; Covid-19; Education; Emergency remo...
# 2       Attitude; Barriers; Distance education; Innova...
# 3       Atomic physics; Blended learning; Distance edu...
# 4       Computer anxiety; Computer self-efficacy; Job ...
#                               ...
# 1262                                                  NaN
# 1263    Distance education; Distance learners; English...
# 1264                                                  NaN
# 1265    Distance education; Leigh University; Online i...
# 1266                                                  NaN
# Name: Author Keywords, Length: 1267, dtype: object

# %%
m38_kw["Author Keywords"] #m38 keyword listesi
# Out:
# 0       Black students; higher education; LGBT; queer ...
# 1       educational opportunity; poverty; racial/ethni...
# 2       education policy; teacher effectiveness; teach...
# 3       clinical education; experimental research; stu...
# 4       accountability; education policy; review; turn...
#                               ...
# 1013                                                  NaN
# 1014                                                  NaN
# 1015                                                  NaN
# 1016                                                  NaN
# 1017                                                  NaN
# Name: Author Keywords, Length: 1018, dtype: object

# %%
m39_kw["Author Keywords"] #m39 keyword listesi
# Out:
# 0       critical thinking ability; metacognitive; read...
# 1       Confirmatory factor analysis; development; exp...
# 2       Ict integration; Pre-service teachers; Science...
# 3       Computational thinking; Didactic suitability c...
# 4       Covid-19; Email communication; Infranodus; Tex...
#                               ...
# 1805    Animals; Behavioural immune system; Environmen...
# 1806    Assessment; Nos; Science and non-science stude...
# 1807    Educational reform; Inquiry-based science educ...
# 1808    Teacher conceptions; Teacher education; Visual...
# 1809    Misconceptions; Photosynthesis; Plant respirat...
# Name: Author Keywords, Length: 1810, dtype: object

# %%
b=str.split(df["Author Keywords"][1],";")
b
# Out:
# ['Cyber security', ' Distance education', ' University students']

# %%
a=str.split(df["Author Keywords"][1798],";")
a
# Out:
# ['análisis de regresión jerárquica',
#  ' aprendizaje virtual',
#  ' Audiovisual',
#  ' Audiovisual educativo',
#  ' competencia digital',
#  ' competencia mediática',
#  ' digital competences',
#  ' distance higher education',
#  ' educación superior a distancia',
#  ' educational technology',
#  ' hierarchical regression analysis',
#  ' learning skills',
#  ' media competences',
#  ' online learning',
#  ' tecnología educativa']

# %%
c=str.split(df["Author Keywords"][2],";")
c
# Out:
# ['Acting path',
#  ' Experiment course',
#  ' Sem analysis',
#  ' Teaching effect',
#  ' Virtual simulation']

# %%
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
stemmer = PorterStemmer()
def stemming(text):
    stem_text = [porter_stemmer.stem(word) for word in text]
    return stem_text
    data['kw']=data['kw_listesi'].apply(lambda x: stemming(x))
